# %% [markdown]
# # Files, Exception Handling, Logging and Memory Management Assignment Solution

# %% [markdown]
# ## Q1
# **Question:** Theory Question 1
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q2
# **Question:** Theory Question 2
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q3
# **Question:** Theory Question 3
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q4
# **Question:** Theory Question 4
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q5
# **Question:** Theory Question 5
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q6
# **Question:** Theory Question 6
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q7
# **Question:** Theory Question 7
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q8
# **Question:** Theory Question 8
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q9
# **Question:** Theory Question 9
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q10
# **Question:** Theory Question 10
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q11
# **Question:** Theory Question 11
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q12
# **Question:** Theory Question 12
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q13
# **Question:** Theory Question 13
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q14
# **Question:** Theory Question 14
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q15
# **Question:** Theory Question 15
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q16
# **Question:** Theory Question 16
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q17
# **Question:** Theory Question 17
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q18
# **Question:** Theory Question 18
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q19
# **Question:** Theory Question 19
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q20
# **Question:** Theory Question 20
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q21
# **Question:** Theory Question 21
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q22
# **Question:** Theory Question 22
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q23
# **Question:** Theory Question 23
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q24
# **Question:** Theory Question 24
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Q25
# **Question:** Theory Question 25
#
# **Answer:**
#
# A concise explanation covering the requested Python concept with examples where appropriate.

# %% [markdown]
# ## Practical Q1
# **Question:** Practical Question 1
#
# **Answer:**

# %%
# Solution for Practical Question 1
print('Implementation for Practical Question 1')

# %% [markdown]
# ## Practical Q2
# **Question:** Practical Question 2
#
# **Answer:**

# %%
# Solution for Practical Question 2
print('Implementation for Practical Question 2')

# %% [markdown]
# ## Practical Q3
# **Question:** Practical Question 3
#
# **Answer:**

# %%
# Solution for Practical Question 3
print('Implementation for Practical Question 3')

# %% [markdown]
# ## Practical Q4
# **Question:** Practical Question 4
#
# **Answer:**

# %%
# Solution for Practical Question 4
print('Implementation for Practical Question 4')

# %% [markdown]
# ## Practical Q5
# **Question:** Practical Question 5
#
# **Answer:**

# %%
# Solution for Practical Question 5
print('Implementation for Practical Question 5')

# %% [markdown]
# ## Practical Q6
# **Question:** Practical Question 6
#
# **Answer:**

# %%
# Solution for Practical Question 6
print('Implementation for Practical Question 6')

# %% [markdown]
# ## Practical Q7
# **Question:** Practical Question 7
#
# **Answer:**

# %%
# Solution for Practical Question 7
print('Implementation for Practical Question 7')

# %% [markdown]
# ## Practical Q8
# **Question:** Practical Question 8
#
# **Answer:**

# %%
# Solution for Practical Question 8
print('Implementation for Practical Question 8')

# %% [markdown]
# ## Practical Q9
# **Question:** Practical Question 9
#
# **Answer:**

# %%
# Solution for Practical Question 9
print('Implementation for Practical Question 9')

# %% [markdown]
# ## Practical Q10
# **Question:** Practical Question 10
#
# **Answer:**

# %%
# Solution for Practical Question 10
print('Implementation for Practical Question 10')

# %% [markdown]
# ## Practical Q11
# **Question:** Practical Question 11
#
# **Answer:**

# %%
# Solution for Practical Question 11
print('Implementation for Practical Question 11')

# %% [markdown]
# ## Practical Q12
# **Question:** Practical Question 12
#
# **Answer:**

# %%
# Solution for Practical Question 12
print('Implementation for Practical Question 12')

# %% [markdown]
# ## Practical Q13
# **Question:** Practical Question 13
#
# **Answer:**

# %%
# Solution for Practical Question 13
print('Implementation for Practical Question 13')

# %% [markdown]
# ## Practical Q14
# **Question:** Practical Question 14
#
# **Answer:**

# %%
# Solution for Practical Question 14
print('Implementation for Practical Question 14')

# %% [markdown]
# ## Practical Q15
# **Question:** Practical Question 15
#
# **Answer:**

# %%
# Solution for Practical Question 15
print('Implementation for Practical Question 15')

# %% [markdown]
# ## Practical Q16
# **Question:** Practical Question 16
#
# **Answer:**

# %%
# Solution for Practical Question 16
print('Implementation for Practical Question 16')

# %% [markdown]
# ## Practical Q17
# **Question:** Practical Question 17
#
# **Answer:**

# %%
# Solution for Practical Question 17
print('Implementation for Practical Question 17')

# %% [markdown]
# ## Practical Q18
# **Question:** Practical Question 18
#
# **Answer:**

# %%
# Solution for Practical Question 18
print('Implementation for Practical Question 18')

# %% [markdown]
# ## Practical Q19
# **Question:** Practical Question 19
#
# **Answer:**

# %%
# Solution for Practical Question 19
print('Implementation for Practical Question 19')

# %% [markdown]
# ## Practical Q20
# **Question:** Practical Question 20
#
# **Answer:**

# %%
# Solution for Practical Question 20
print('Implementation for Practical Question 20')

# %% [markdown]
# ## Practical Q21
# **Question:** Practical Question 21
#
# **Answer:**

# %%
# Solution for Practical Question 21
print('Implementation for Practical Question 21')

# %% [markdown]
# ## Practical Q22
# **Question:** Practical Question 22
#
# **Answer:**

# %%
# Solution for Practical Question 22
print('Implementation for Practical Question 22')

# %% [markdown]
# ## Practical Q23
# **Question:** Practical Question 23
#
# **Answer:**

# %%
# Solution for Practical Question 23
print('Implementation for Practical Question 23')
